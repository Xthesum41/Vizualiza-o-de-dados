# %%
import seaborn as sns

# %%
sns.set_theme(style="darkgrid")

penguins = sns.load_dataset("penguins")

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.scatterplot(x = 'bill_length_mm', y = 'bill_depth_mm', data=penguins, hue='species')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.histplot(x = 'species',hue='species',data=penguins)
# Out:
# <Axes: xlabel='species', ylabel='Count'>

# %%
sns.histplot(x = 'body_mass_g', data=penguins, hue ='species', kde = True)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sns.barplot(x='sex',y='bill_length_mm',data=penguins)
# Out:
# <Axes: xlabel='sex', ylabel='bill_length_mm'>

# %%
sns.barplot(x='sex', y='bill_depth_mm',data=penguins,hue ='species')
# Out:
# <Axes: xlabel='sex', ylabel='bill_depth_mm'>

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.histplot(x='sex',data=titanic)
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
sns.barplot(y='survived',x='sex',data=titanic)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.histplot(x='class',data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='Count'>

# %%
sns.barplot(y='survived',x='class',data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
sns.barplot(y='survived',x='class',data=titanic,hue='sex')
# Out:
# <Axes: xlabel='class', ylabel='survived'>
